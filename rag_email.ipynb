# %%
from dotenv import load_dotenv
from custom_gmail_reader import CustomGmailReader
from llama_index.core import Settings
from llama_index.core.callbacks import CallbackManager
from langfuse.llama_index import LlamaIndexCallbackHandler

load_dotenv()

# ... rest of the code ...
 
langfuse_callback_handler = LlamaIndexCallbackHandler()
Settings.callback_manager = CallbackManager([langfuse_callback_handler])

# Instantiate the CustomGmailReader
loader = CustomGmailReader(
    query="",
    max_results=50,
    results_per_page=10,
    service=None
)

# Load the emails
documents = loader.load_data()

# Print email information
print(f"Number of documents: {len(documents)}")
for i, doc in enumerate(documents[:20]):
    print(f"Document {i+1}:")
    print(f"To: {doc.metadata.get('to', 'N/A')}")
    print(f"From: {doc.metadata.get('from', 'N/A')}")
    print(f"Subject: {doc.metadata.get('subject', 'N/A')}")
    print(f"Date: {doc.metadata.get('date', 'N/A')}")
    print(f"Content snippet: {doc.text[:1000]}...")
    print("=" * 50)
# Out:
# Number of documents: 50
# Document 1:
# To: feiyang.f@gmail.com
# From: Conservice <ebill@ebill.conservicemail.com>
# Subject: Monthly Conservice Statement for The Paramount 75380
# Date: Sat, 21 Sep 2024 01:10:13 +0000
# Content snippet: ...
# ==================================================
# Document 2:
# To: feiyang.f@gmail.com
# From: "JOE & THE JUICE" <Joe@news.e.joejuice.com>
# Subject: Not Your Basic PSL 🎃
# Date: Sat, 21 Sep 2024 00:11:27 +0000
# Content snippet: Seasonal flavours have arrived!🍂 Try our Pumpkin Spiced Lattes
# and taste the difference🎃
# ( https://clicks.joejuice.com/f/a/q7SRoTUMgoIicC0K85gnYw~~/AAAHagA~/RgRo0JQvP0QraHR0cHM6Ly9qb2VhbmR0aGVqdWljZS5hcHAubGluay8wbGlhNkpHT3RNYlcFc3BjZXVCCmbPLw_uZkYlQdJSE2ZlaXlhbmcuZkBnbWFpbC5jb21YBAAAAOE~ )
#
# *****************************************************************
# ( https://clicks.joejuice.com/f/a/ETqduOth8GBJxXwU2kYp8Q~~/AAAHagA~/RgRo0JQvP0QZaHR0cHM6Ly93d3cuam9lanVpY2UuY29tL1cFc3BjZXVCCmbPLw_uZkYlQdJSE2ZlaXlhbmcuZkBnbWFpbC5jb21YBAAAAOE~ )  Facebook
# ( https://clicks.joejuice.com/f/a/Z3EUbLo57L8hDcNU3g7c6Q~~/AAAHagA~/RgRo0JQvP0Q1aHR0cHM6Ly93d3cuZmFjZWJvb2suY29tL2pvZWFuZHRoZWp1aWNlLz9sb2NhbGU9ZW5fR0JXBXNwY2V1Qgpmzy8P7mZGJUHSUhNmZWl5YW5nLmZAZ21haWwuY29tWAQAAADh ) Instagram
# ( https://clicks.joejuice.com/f/a/DiKUoALh5g-iFw5NdoKzIA~~/AAAHagA~/RgRo0JQvP0QvaHR0cHM6Ly93d3cuaW5zdGFncmFtLmNvbS9qb2VhbmR0aGVqdWljZS8_aGw9ZW5XBXNwY2V1Qgpmzy8P7mZGJUHSUhNmZWl5YW5nLmZAZ21haWwuY29tWAQAAADh ) LinkedIn
# ( ht...
# ==================================================
# Document 3:
# To: feiyang.f@gmail.com
# From: The Paramount <no-reply@rentcafe.com>
# Subject: The Paramount | Unscheduled Maintenance Repair - Update
# Date: Fri, 20 Sep 2024 18:50:46 -0500 (CDT)
# Content snippet: ...
# ==================================================
# Document 4:
# To: feiyang.f@gmail.com
# From: DRAE <no-reply@loox.io>
# Subject: We'd love your feedback Sophia 🖤
# Date: Fri, 20 Sep 2024 22:33:16 +0000 (UTC)
# Content snippet: ...
# ==================================================
# Document 5:
# To: feiyang.f@gmail.com
# From: Victoria Beckham Beauty <support@victoriabeckhambeauty.com>
# Subject: Highly Favoured
# Date: Fri, 20 Sep 2024 21:21:07 +0000 (UTC)
# Content snippet: ...
# ==================================================
# Document 6:
# To: feiyang.f@gmail.com
# From: BNTO <support@bnto.rent>
# Subject: YOUR BNTO HAS BEEN DELIVERED
# Date: Fri, 20 Sep 2024 20:37:02 +0000 (UTC)
# Content snippet: ...
# ==================================================
# Document 7:
# To: feiyang.f@gmail.com
# From: "[solidcore] California" <Business5723396@mindbodyonline.com>
# Subject: Receipt for your [solidcore] CA, Castro purchase
# Date: Fri, 20 Sep 2024 19:04:32 +0000 (UTC)
# Content snippet: ...
# ==================================================
# Document 8:
# To: feiyang.f@gmail.com
# From: "[solidcore] California" <Business5723396@mindbodyonline.com>
# Subject: Receipt for your [solidcore] CA, Castro purchase
# Date: Fri, 20 Sep 2024 19:03:20 +0000 (UTC)
# Content snippet: ...
# ==================================================
# Document 9:
# To: Sophia Feng <feiyang.f@gmail.com>
# From: Cymbiotika <donotreply@cymbiotika.com>
# Subject: Your Cymbiotika Subscription is About to Ship!
# Date: Fri, 20 Sep 2024 18:49:09 +0000 (UTC)
# Content snippet: Hi Sophia,
#
# Thank you for being a valued subscriber and a cherished member of our Arise Community!
#
# Your next Cymbiotika subscription order is scheduled to process in just 3 business days!
#
# Need to make changes or delay your next shipment? Simply log into your account portal—just use feiyang.f@gmail.com to access your account and make adjustments with ease.
#
# Click here to log into your account portal.
#
# If you have any questions or need assistance, we’re here to help. Simply reply to this email, or feel free to reach out at info@cymbiotika.com or give us a call at 1-855-983-8888.
#
# P.S. As a loyal subscriber, you’ll receive these reminders 3 days before your next order processes. We're dedicated to making your experience seamless and keeping you informed! ✨
#
# With appreciation,
# Your Cymbiotika Family
#
# You received this email from Cymbiotika. If you would like to unsubscribe, [click here](https://manage.kmail-lists.com/subscriptions/unsubscribe?a=Hd3Va6&c=01HEH3CK5Q...
# ==================================================
# Document 10:
# To: feiyang.f@gmail.com
# From: NAMA <info@namaclo.com>
# Subject: A shipment from order #137994 has been delivered
# Date: Fri, 20 Sep 2024 18:14:43 +0000 (UTC)
# Content snippet: Some items in your order have been delivered
#
# *****************************************************************
# NAMA
# ( https://namaclo.com?syclid=39aa7e86-02eb-41cf-b9bb-e9e114010d36 )
# *****************************************************************
#
# Order #137994
#
# --------------------------------------------
# Some items in your order have been delivered
# --------------------------------------------
#
# Haven't received your package yet? Let us know
# ( info@namaclo.com )
#
# View your order
# ( https://namaclo.com/16053707/orders/ee061a79f377bebadb5f5181fdb0f886/authenticate?key=34ab6c565d21181ccb7150d25bcbcd43&syclid=6d66f75b-361a-445c-9ed8-dcb72c975b7b )
#
#
# or Visit our store
# ( https://namaclo.com?syclid=73308a50-261f-4aae-9584-efe5d785dc2e )
#
# USPS tracking number: 9434636206574965983832
# ( https://tools.usps.com/go/TrackConfirmAction.action?tRef=fullpage&tLc=1&text28777=&tLabels=9434636206574965983832 )
#
#
# Items in this shipment
# ----------------------
#
# LUXKNIT™ ...
# ==================================================
# Document 11:
# To: Sophia Feng <feiyang.f@gmail.com>
# From: barre3 Willow Glen <willowglen@barre3.com>
# Subject: 🆕 Exciting updates from barre3 Willow Glen
# Date: Fri, 20 Sep 2024 18:08:12 +0000 (UTC)
# Content snippet: ...
# ==================================================
# Document 12:
# To: Sophia Feng <feiyang.f@gmail.com>
# From: Elix <hello@elixhealing.com>
# Subject: Your Elix package just shipped!
# Date: Fri, 20 Sep 2024 17:04:26 +0000 (UTC)
# Content snippet: [Company Name](https://elixhealing.com/)
#
# Your package is on its way!
#
# We're excited to let you know that your order has been shipped - natural menstrual wellness support will be at your door soon.
#
# [TRACK MY ORDER](https://elix.mymalomo.com/asbw1g/index.html?_m_id=02a59427-e567-451d-9261-5462e36cce2a)
#
# The below items shipped
#
# [item.title]
#
# Cycle Balance Quarterly Subscription
#
# Quantity: 1
#
# [item.title]
#
# Ginger Aide 1 oz
#
# Quantity: 1
#
# Subtotal
#
# Tax
#
# Shipping
#
# Total
#
# $122.40
#
# $0.00
#
# $0.00
#
# $122.40
#
# Shipping Address
#
# Sophia Feng
# 680 Mission Street
# 15B
# San Francisco, CA 94105
# United States
#
# Shipping Method:
#
# USPS
#
# Tracking Number:
#
# 420941059261290304418105560280
#
# Discover Elix Wellness
#
# From digestive support to immune and anti-inflammatory support. Our Wellness line offers clinically-tested blends of herbs and adaptogens for everyday health.
#
# [Image of Daily Harmony](https://elix-healing.myshopify.com/products/daily-harmony)
#
# ...
# ==================================================
# Document 13:
# To: feiyang.f@gmail.com
# From: Substack <no-reply@substack.com>
# Subject: You read 221612 words on Substack this summer
# Date: Fri, 20 Sep 2024 16:39:20 +0000
# Content snippet: ...
# ==================================================
# Document 14:
# To: feiyang.f@gmail.com
# From: The Paramount <no-reply@rentcafe.com>
# Subject: The Paramount | Unscheduled Maintenance Repair
# Date: Fri, 20 Sep 2024 10:09:45 -0500 (CDT)
# Content snippet: ...
# ==================================================
# Document 15:
# To: Sophia Feng <feiyang.f@gmail.com>
# From: Kith <newsletter@kith.com>
# Subject: Fall 2024 | Seasonal Selects
# Date: Fri, 20 Sep 2024 15:05:05 +0000 (UTC)
# Content snippet: https://kith.com/
#
# https://kith.com/
#
# KITH FALL 2024
#
# Seasonal Selects
#
# Shop Now
#
# https://kith.com/collections/kith-fall-2024
#
# Premium outerwear, transitional layering pieces, and a variety of accessories such as our new Monogram-suede bags, scarves and headwear highlight the Fall 2024 collection.
#
# [SHOP NOW](https://kith.com/collections/kith-fall-2024)
#
# [Image of Kith Wrinkle Nylon Madison Jacket - Kindling](https://kithnyc.myshopify.com/products/khm010610-211)
#
# [Image of Kith Wrinkle Nylon Madison Jacket - Torpedo](https://kithnyc.myshopify.com/products/khm010610-402)
#
# [Image of Kith Wrinkle Nylon Elias Pant - Kindling](https://kithnyc.myshopify.com/products/khm060694-211)
#
# [Image of Kith Wrinkle Nylon Mercer 8 Pant - Torpedo](https://kithnyc.myshopify.com/products/khm060709-402)
#
# [Image of Kith Paper Nylon Ryder Quarter Zip - Island](https://kithnyc.myshopify.com/products/khm032303-165)
#
# [Image of Kith Paper Nylon Ryder Quarter Zip - Black](https://kithnyc...
# ==================================================
# Document 16:
# To: feiyang.f@gmail.com
# From: NAMA <info@namaclo.com>
# Subject: A shipment from order #137994 is out for delivery
# Date: Fri, 20 Sep 2024 14:10:59 +0000 (UTC)
# Content snippet: Some items in your order are out for delivery
#
# *****************************************************************
# NAMA
# ( https://namaclo.com?syclid=6d944177-03fa-42dd-be85-89704109f45f )
# *****************************************************************
#
# Order #137994
#
# ---------------------------------------------
# Some items in your order are out for delivery
# ---------------------------------------------
#
# Some items in your order are out for delivery. Track
# your shipment to see the delivery status.
#
# Estimated delivery date: September 21, 2024
#
# Track my shipment
# ( https://namaclo.com/16053707/orders/ee061a79f377bebadb5f5181fdb0f886/authenticate?key=34ab6c565d21181ccb7150d25bcbcd43&syclid=c3a762ef-8bea-4249-b778-696f0ae673ea )
#
#
# or Visit our store
# ( https://namaclo.com?syclid=705e424c-7588-4a7d-9030-56ec07ceb51b )
#
# USPS tracking number: 9434636206574965983832
# ( https://tools.usps.com/go/TrackConfirmAction.action?tRef=fullpage&tLc=1&text28777=&tLabels=943463620...
# ==================================================
# Document 17:
# To: feiyang.f@gmail.com
# From: TestFlight <no_reply@email.apple.com>
# Subject: Whatnot - Live Video Shopping 4.34.0 (6) for iOS is now available to test.
# Date: Fri, 20 Sep 2024 14:04:24 +0000 (GMT)
# Content snippet: ...
# ==================================================
# Document 18:
# To: Sophia Feng <feiyang.f@gmail.com>
# From: Sisterhood <contact@join-the-sisterhood.com>
# Subject: 💗 FLASH SALE 💗 25% OFF SITEWIDE
# Date: Fri, 20 Sep 2024 12:32:22 +0000 (UTC)
# Content snippet: [Sisterhood](http://www.join-the-sisterhood.com)
#
# https://join-the-sisterhood.com/discount/SEPTEMBER
#
#
#
#
#
# Get ready for a new season
# 25% off everything online, including sale
#
# USE CODE : SEPTEMBER
#
#
#
# [SHOP NOW](https://join-the-sisterhood.com/discount/SEPTEMBER)
#
#
#
#
#
#
#
#
#
# [Contact Us](mailto:contact@join-the-sisterhood.com)  |  [Instagram](https://www.instagram.com/sisterhoodthe/)  |  [Facebook](https://www.instagram.com/sisterhoodthe/)
#
# [Sisterhood](http://www.join-the-sisterhood.com)
#
#  [Unsubscribe](https://manage.kmail-lists.com/subscriptions/unsubscribe?a=WUMz7z&c=01J6RKRAEA4DNFC18N0HZMERCB&k=cc23a352724ccaeb5595778c32f8ffb3&m=01J87N0BQ2SGRVWKNAYB3MEEQB&r=3dC2pMgr)...
# ==================================================
# Document 19:
# To: feiyang.f@gmail.com
# From: App Store Connect <no_reply@email.apple.com>
# Subject: Your submission was accepted.
# Date: Fri, 20 Sep 2024 11:50:39 +0000 (GMT)
# Content snippet: Hello,
#
# Congratulations!
#
# Your submission was accepted for distribution.
#
# App Name: Whatnot - Live Video Shopping
# Submission ID: ca8ee8b9-f8ab-4270-94ed-4b3f4dcc238e
#
# Best regards,
# App Store Review...
# ==================================================
# Document 20:
# To: "feiyang.f@gmail.com" <feiyang.f@gmail.com>
# From: Bay Area Times <bayareatimes@bayareatimes.com>
# Subject: 🗞️ OpenAI’s oversubscribed round
# Date: Fri, 20 Sep 2024 10:25:35 +0000 (UTC)
# Content snippet: View image: (https://media.beehiiv.com/cdn-cgi/image/fit=scale-down,format=auto,onerror=redirect,quality=80/uploads/asset/file/e17c23f3-58a2-4d15-b965-192be2687e69/Bay_Area_Times_email.png)
# Caption:
#
# ----------
# Brought to you by:
#
# View image: (https://media.beehiiv.com/cdn-cgi/image/fit=scale-down,format=auto,onerror=redirect,quality=80/uploads/asset/file/1cd5ab7f-6f09-4e5c-8431-0144facabdbd/Athyna_-_Logo_-_Blue.png?t=1715288021)
# Follow image link: (https://partnerslink.athyna.com/BAT_Ad_Athyna_Logo)
# Caption:
#
#
# --------------------
# [Follow us on X](https://twitter.com/bayareatimes) | [Instagram](https://www.instagram.com/bayareatimescom/) | [Advertise](https://magic.beehiiv.com/v1/87a70690-278a-4132-97e4-7688c20a1313?email=feiyang.f@gmail.com&redirect_to=https://advertise.bayareatimes.com/p/start)
#
#
# ----------# 0. Data and calendar
#
# View image: (https://media.beehiiv.com/cdn-cgi/image/fit=scale-down,format=auto,onerror=redirect,quality=80/uploads/asset/file/eaf09460-...
# ==================================================

# %%
from dotenv import load_dotenv
from llama_index.core import VectorStoreIndex
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core.callbacks import CallbackManager
from langfuse.llama_index import LlamaIndexCallbackHandler
langfuse_callback_handler = LlamaIndexCallbackHandler()
Settings.callback_manager = CallbackManager([langfuse_callback_handler])


load_dotenv()

# Create index
index = VectorStoreIndex.from_documents(documents)

# Create retriever
retriever = VectorIndexRetriever(index=index)

# Create query engine
query_engine = RetrieverQueryEngine(retriever=retriever)

# Example query
# response = query_engine.query("Did I get off the waitlist for any of the Solidcore classes?")
response = query_engine.query("DId the latest app get accepted by the app store?")
print(response)

langfuse_callback_handler.flush()
# Out:
# You did not mention in your message whether you got off the waitlist for any of the Solidcore classes.
